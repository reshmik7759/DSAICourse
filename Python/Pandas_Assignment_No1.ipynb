# %% [markdown]
# # Pandas Assignment No 1

# %%
import pandas as pd

# %%
#dataset :https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %%
f1 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")

# %%
#print first 5 and last 7 records
f1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#print last 7 records
f1.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
# print total records and type of variables
f1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
#Print the name of all the columns
f1.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#How is the dataset indexed?
f1.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Which was the most ordered item? and How many items were ordered?

c = f1.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
#What was the most ordered item in the choice_description column?
c = f1.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
#Turn the item price into a float
def num_float(x):
    return float(x[1:-1])

# %%
f1.item_price = f1.item_price.apply(num_float)

# %%
f1.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
#print a data frame with only two columns item_name and item_price
f2 = f1[['item_name','item_price']]
f2.head()
# Out:
#                                item_name  item_price
# 0           Chips and Fresh Tomato Salsa        2.39
# 1                                   Izze        3.39
# 2                       Nantucket Nectar        3.39
# 3  Chips and Tomatillo-Green Chili Salsa        2.39
# 4                           Chicken Bowl       16.98

# %%
# delete the duplicates in item_name and quantity
f1.drop_duplicates(['item_name','item_price'])
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4237      1691         2                    Chips and Guacamole
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
# 4509      1793         1                                  Chips
# 4510      1793         1                          Barbacoa Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# select only the products with quantity equals to 1
one =f1[f1["quantity"] == 1]
one
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# select only the item_name and item_price columns
f3 = f1[['item_name','item_price']]
f3.head(10)
# Out:
#                                item_name  item_price
# 0           Chips and Fresh Tomato Salsa        2.39
# 1                                   Izze        3.39
# 2                       Nantucket Nectar        3.39
# 3  Chips and Tomatillo-Green Chili Salsa        2.39
# 4                           Chicken Bowl       16.98
# 5                           Chicken Bowl       10.98
# 6                          Side of Chips        1.69
# 7                          Steak Burrito       11.75
# 8                       Steak Soft Tacos        9.25
# 9                          Steak Burrito        9.25

# %%
# sort item from the most to less expensive
f4=f1.sort_values(['item_price'], ascending=False)
f4
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3936      1578         1                   Canned Soda
# 2922      1162         1                 Bottled Water
# 1396       567         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# 1457       591         1                   Canned Soda
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# ...

# %%
#What was the quantity of the most expensive item ordered?
f5= f4[['item_name','quantity','item_price']].head(1)
f5
# Out:
#                          item_name  quantity  item_price
# 3598  Chips and Fresh Tomato Salsa        15       44.25

# %%
#How many times were a Veggie Salad Bowl ordered?
veggie =f1[f1.item_name == "Veggie Salad Bowl"]
print("How many times were a Veggie Salad Bowl ordered = ",len(veggie))
# Out:
# How many times were a Veggie Salad Bowl ordered =  18

# %% [markdown]
# # End
