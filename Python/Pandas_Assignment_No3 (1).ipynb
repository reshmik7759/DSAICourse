# %% [markdown]
# # Pandas Assignment No 3

# %%
import pandas as pd

# %%
#dataset1 :https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv
#dataset 2:https://raw.githubusercontent.com/kjam/data-wranglingpycon/master/data/berlin_weather_oldest.csv

# %%
df=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
#1. Get the Metadata from the above files.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATION       117208 non-null  object
#  1   STATION_NAME  117208 non-null  object
#  2   DATE          117208 non-null  int64
#  3   PRCP          117208 non-null  int64
#  4   SNWD          117208 non-null  int64
#  5   SNOW          117208 non-null  int64
#  6   TMAX          117208 non-null  int64
#  7   TMIN          117208 non-null  int64
#  8   WDFG          117208 non-null  int64
#  9   PGTM          117208 non-null  int64
#  10  WSFG          117208 non-null  int64
#  11  WT09          117208 non-null  int64
#  12  WT07          117208 non-null  int64
#  13  WT01          117208 non-null  int64
#  14  WT06          117208 non-null  int64
#  15  WT05          117208 non-null  int64
#  16  WT04          117208 non-null  int64
#  17  WT16          117208 non-null  int64
# ...

# %%
#2. Get the row names from the above files.
print(" First Dataset Rows:")
df.index.values
# Out:
#  First Dataset Rows:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
#2. Get the row names from the above files.
print(" Second Dataset Rows:")
df1.index.values
# Out:
#  Second Dataset Rows:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
#3. Change the column name from any of the above file and store the changes made permanently
df.rename(columns={"Sex":"Gender"},inplace=True)   
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#        Gender  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
#3. Change the column name from any of the above file and store the changes made permanently
df1.rename(columns={"STATION":"STATION_ID"},inplace=True)   
df1.head()
# Out:
#           STATION_ID         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
#4. Change the names of multiple columns.
df1.rename(columns={"WT09":"WT009","WT07":"WT007","WT06":"WT006"},inplace=True)   
df1.head()
# Out:
#           STATION_ID         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...  WT009  WT007  WT01  WT006  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# ...

# %%
#4. Change the names of multiple columns.
df.rename(columns={"Gender":"SEX","Year":"YEAR"},inplace=True)   
df.head()
# Out:
#                            Indicator PUBLISH STATES  YEAR  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           SEX  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
#5. Arrange values of a particular column in ascending order.
df.sort_values('Numeric').head(5)
# Out:
#                               Indicator PUBLISH STATES  YEAR WHO region  \
# 265   Life expectancy at age 60 (years)      Published  2000     Africa
# 1476  Life expectancy at age 60 (years)      Published  1990     Africa
# 1474  Life expectancy at age 60 (years)      Published  1990     Africa
# 3070  Life expectancy at age 60 (years)      Published  2000     Africa
# 3072  Life expectancy at age 60 (years)      Published  2000     Africa
#
#      World Bank income group       Country         SEX  Display Value  \
# 265               Low-income  Sierra Leone        Male             11
# 1476              Low-income  Sierra Leone      Female             11
# 1474              Low-income  Sierra Leone        Male             11
# 3070              Low-income  Sierra Leone      Female             11
# 3072              Low-income  Sierra Leone  Both sexes             11
#
#       Numeric  Low  High  Comments
# 265      11.0  NaN   NaN       NaN
# 1476     11.0  NaN   NaN       NaN
# ...

# %%
#5. Arrange values of a particular column in ascending order.
df1.sort_values('TMAX').head(5)
# Out:
#               STATION_ID         STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 0      GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999
# 96934  GHCND:GME00121150      BERLIN TEGEL GM  19410216 -9999 -9999 -9999
# 96950  GHCND:GME00121150      BERLIN TEGEL GM  19410305 -9999 -9999 -9999
# 96972  GHCND:GME00121150      BERLIN TEGEL GM  19410327 -9999 -9999 -9999
# 97003  GHCND:GME00121150      BERLIN TEGEL GM  19410427    51 -9999 -9999
#
#        TMAX  TMIN  WDFG  PGTM  ...  WT009  WT007  WT01  WT006  WT05  WT04  \
# 0     -9999   -11 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999
# 96934 -9999   -11 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999
# 96950 -9999    39 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999
# 96972 -9999   -22 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999
# 97003 -9999    22 -9999 -9999  ...  -9999  -9999 -9999  -9999 -9999 -9999
#
#        WT16  WT08  WT18  WT03
# 0     -9999 -9999 -9999 -9999
# ...

# %%
#6. Arrange multiple column values in ascending order.
df[0:25].sort_values(['YEAR','Indicator','Country']).head()
# Out:
#                             Indicator PUBLISH STATES  YEAR  \
# 6   Life expectancy at age 60 (years)      Published  1990
# 16  Life expectancy at age 60 (years)      Published  1990
# 22  Life expectancy at age 60 (years)      Published  1990
# 0    Life expectancy at birth (years)      Published  1990
# 15   Life expectancy at birth (years)      Published  1990
#
#                WHO region World Bank income group              Country  \
# 6                Americas             High-income  Antigua and Barbuda
# 16  Eastern Mediterranean             High-income              Bahrain
# 22        Western Pacific             High-income    Brunei Darussalam
# 0                  Europe             High-income              Andorra
# 15  Eastern Mediterranean             High-income              Bahrain
#
#            SEX  Display Value  Numeric  Low  High  Comments
# 6         Male             17     17.0  NaN   NaN       NaN
# 16        Male             17     17.0  NaN   NaN       NaN
# ...

# %%
#7. Make country as the first column of the dataframe.
df.set_index('Country').head()
# Out:
#                                               Indicator PUBLISH STATES  YEAR  \
# Country
# Andorra                Life expectancy at birth (years)      Published  1990
# Andorra                Life expectancy at birth (years)      Published  2000
# Andorra               Life expectancy at age 60 (years)      Published  2012
# Andorra               Life expectancy at age 60 (years)      Published  2000
# United Arab Emirates   Life expectancy at birth (years)      Published  2012
#
#                                  WHO region World Bank income group  \
# Country
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# United Arab Emirates  Eastern Mediterranean             High-income
#
# ...

# %%
#Get the column array using a variable
import numpy as np
C=np.array(df[['Numeric']],dtype=np.int)
C
# Out:
# array([[77],
#        [80],
#        [28],
#        ...,
#        [49],
#        [36],
#        [51]])

# %%
#9. Get the subset rows 11, 24, 37
df.loc[[11,24,37]]
# Out:
#                             Indicator PUBLISH STATES  YEAR       WHO region  \
# 11   Life expectancy at birth (years)      Published  2012           Europe
# 24  Life expectancy at age 60 (years)      Published  2012  Western Pacific
# 37  Life expectancy at age 60 (years)      Published  2012           Europe
#
#    World Bank income group            Country     SEX  Display Value  Numeric  \
# 11             High-income            Austria  Female             83     83.0
# 24             High-income  Brunei Darussalam  Female             21     21.0
# 37             High-income             Cyprus  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %%
#10. Get the subset rows excluding 5, 12, 23, and 56
df.drop([5,12,23,56])[0:56]
# Out:
#                             Indicator PUBLISH STATES  YEAR  \
# 0    Life expectancy at birth (years)      Published  1990
# 1    Life expectancy at birth (years)      Published  2000
# 2   Life expectancy at age 60 (years)      Published  2012
# 3   Life expectancy at age 60 (years)      Published  2000
# 4    Life expectancy at birth (years)      Published  2012
# 6   Life expectancy at age 60 (years)      Published  1990
# 7   Life expectancy at age 60 (years)      Published  2012
# 8    Life expectancy at birth (years)      Published  2012
# 9    Life expectancy at birth (years)      Published  2000
# 10   Life expectancy at birth (years)      Published  2012
# 11   Life expectancy at birth (years)      Published  2012
# 13   Life expectancy at birth (years)      Published  2012
# 14   Life expectancy at birth (years)      Published  2000
# 15   Life expectancy at birth (years)      Published  1990
# 16  Life expectancy at age 60 (years)      Published  1990
# ...

# %%
#11.find rows with NaN values

df1.isnull()
# Out:
#         STATION_ID  STATION_NAME   DATE   PRCP   SNWD   SNOW   TMAX   TMIN  \
# 0            False         False  False  False  False  False  False  False
# 1            False         False  False  False  False  False  False  False
# 2            False         False  False  False  False  False  False  False
# 3            False         False  False  False  False  False  False  False
# 4            False         False  False  False  False  False  False  False
# ...            ...           ...    ...    ...    ...    ...    ...    ...
# 117203       False         False  False  False  False  False  False  False
# 117204       False         False  False  False  False  False  False  False
# 117205       False         False  False  False  False  False  False  False
# 117206       False         False  False  False  False  False  False  False
# 117207       False         False  False  False  False  False  False  False
#
# ...

# %%
#12. show rows from dataset 1 country = india with high income
IND=df[df['Country']=='India']    
IND

try:
    df[df['Country']=='India'] & df[df['World Bank income group']=='High-income']
except:
    df[df['Country']=='India'].max()
df[df['Country']=='India'].max()
# Out:
# Indicator                  Life expectancy at birth (years)
# PUBLISH STATES                                    Published
# YEAR                                                   2012
# WHO region                                  South-East Asia
# World Bank income group                 Lower-middle-income
# Country                                               India
# SEX                                                    Male
# Display Value                                            68
# Numeric                                                  68
# Low                                                    None
# High                                                   None
# Comments                                               None
# dtype: object

# %% [markdown]
# # END
